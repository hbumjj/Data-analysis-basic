# %%
# 시험환경 세팅 (코드 변경 X)
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

def exam_data_load(df, target, id_name="", null_name=""):
    if id_name == "":
        df = df.reset_index().rename(columns={"index": "id"})
        id_name = 'id'
    else:
        id_name = id_name
    
    if null_name != "":
        df[df == null_name] = np.nan
    
    X_train, X_test = train_test_split(df, test_size=0.2, random_state=2021)
    
    y_train = X_train[[id_name, target]]
    X_train = X_train.drop(columns=[target])

    
    y_test = X_test[[id_name, target]]
    X_test = X_test.drop(columns=[target])
    return X_train, X_test, y_train, y_test 

path = "C:/Users/rapa/Desktop/빅데이터분석기사실기/"
df = pd.read_csv(path + "diabetes.csv")
X_train, X_test, y_train, y_test = exam_data_load(df, target='Outcome')

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((614, 9), (154, 9), (614, 2), (154, 2))

# %%
X_train.head()
# Out:
#       id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 147  147            2      106             64             35      119  30.5
# 344  344            8       95             72              0        0  36.8
# 390  390            1      100             66             29      196  32.0
# 150  150            1      136             74             50      204  37.4
# 132  132            3      170             64             37      225  34.5
#
#      DiabetesPedigreeFunction  Age
# 147                     1.400   34
# 344                     0.485   57
# 390                     0.444   42
# 150                     0.399   24
# 132                     0.356   30

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
X_train.head()

g = X_train[X_train['Glucose'] == 0].index
bl = X_train[X_train['BloodPressure'] == 0].index
s = X_train[X_train['SkinThickness'] == 0].index
i = X_train[X_train['Insulin'] == 0].index
b = X_train[X_train['BMI'] == 0].index

cols = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
cols_mean = X_train[cols].mean()
print(cols_mean)

X_train = X_train.loc[:,cols].replace(0,cols_mean)

X_train
# Out:
# Glucose          120.705212
# BloodPressure     68.530945
# SkinThickness     20.982085
# Insulin           82.229642
# BMI               31.948534
# dtype: float64
#      Glucose  BloodPressure  SkinThickness     Insulin   BMI
# 147    106.0           64.0      35.000000  119.000000  30.5
# 344     95.0           72.0      20.982085   82.229642  36.8
# 390    100.0           66.0      29.000000  196.000000  32.0
# 150    136.0           74.0      50.000000  204.000000  37.4
# 132    170.0           64.0      37.000000  225.000000  34.5
# ..       ...            ...            ...         ...   ...
# 621     92.0           76.0      20.000000   82.229642  24.2
# 128    117.0           88.0      24.000000  145.000000  34.5
# 57     100.0           88.0      60.000000  110.000000  46.8
# 341     95.0           74.0      21.000000   73.000000  25.9
# 116    124.0           74.0      20.982085   82.229642  34.0
#
# [614 rows x 5 columns]

# %%
X_test.head()

g = X_test[X_test['Glucose'] == 0].index
bl = X_test[X_test['BloodPressure'] == 0].index
s = X_test[X_test['SkinThickness'] == 0].index
i = X_test[X_test['Insulin'] == 0].index
b = X_test[X_test['BMI'] == 0].index

cols = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
cols_mean = X_test[cols].mean()
print(cols_mean)

X_test = X_test.loc[:,cols].replace(0,cols_mean)

X_test
# Out:
# Glucose          121.649351
# BloodPressure     71.396104
# SkinThickness     18.759740
# Insulin           70.110390
# BMI               32.168182
# dtype: float64
#      Glucose  BloodPressure  SkinThickness    Insulin   BMI
# 258      193           50.0       16.00000  375.00000  25.9
# 220      177           60.0       29.00000  478.00000  34.6
# 438       97           70.0       15.00000   70.11039  18.2
# 130      173           70.0       14.00000  168.00000  29.7
# 730      130           78.0       23.00000   79.00000  28.4
# ..       ...            ...            ...        ...   ...
# 678      121           52.0       18.75974   70.11039  36.0
# 500      117           90.0       19.00000   71.00000  25.2
# 256      111           56.0       39.00000   70.11039  30.1
# 80       113           44.0       13.00000   70.11039  22.4
# 174       75           64.0       24.00000   55.00000  29.7
#
# [154 rows x 5 columns]

# %%
import numpy as np

scaler = StandardScaler()
cols = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
X_train[cols] = scaler.fit_transform(X_train[cols])
X_test[cols] = scaler.fit_transform(X_test[cols])


X_train
# Out:
#       Glucose  BloodPressure  SkinThickness   Insulin       BMI
# 147 -0.521265      -0.673425       0.832457 -0.017641 -0.287209
# 344 -0.886758       0.000760      -0.619369 -0.407009  0.656751
# 390 -0.720625      -0.504878       0.211041  0.797725 -0.062456
# 150  0.475535       0.169307       2.385998  0.882438  0.746652
# 132  1.605242      -0.673425       1.039596  1.104810  0.312131
# ..        ...            ...            ...       ...       ...
# 621 -0.986438       0.337853      -0.721083 -0.407009 -1.231169
# 128 -0.155772       1.349130      -0.306806  0.257677  0.312131
# 57  -0.720625       1.349130       3.421691 -0.112944  2.155100
# 341 -0.886758       0.169307      -0.617514 -0.504743 -0.976449
# 116  0.076815       0.169307      -0.619369 -0.407009  0.237213
#
# [614 rows x 5 columns]

# %%
model = RandomForestClassifier()

y_train_value = y_train['Outcome']

model.fit(X_train, y_train_value)
# Out:
# RandomForestClassifier()

# %%
train_pred = model.predict(X_train)

a = accuracy_score(train_pred, y_train_value)
print(a)
# Out:
# 1.0

# %%
test_pred = model.predict(X_test)
y_test_value = y_test['Outcome']
a = accuracy_score(test_pred, y_test_value)

print(a)
# Out:
# 0.7792207792207793
