# %%
import pandas as pd

df1 = pd.read_csv("C:/Users/rapa/Desktop/빅데이터분석기사실기/basic1(20).csv")
df2 = pd.read_csv("C:/Users/rapa/Desktop/빅데이터분석기사실기/basic3(20).csv")

print(df1.head())
df2
# Out:
#      id   age city    f1  f2   f3    f4         f5
# 0  id01   2.0   서울   NaN   0  NaN  ENFJ  91.297791
# 1  id02   9.0   서울  70.0   1  NaN  ENFJ  60.339826
# 2  id03  27.0   서울  61.0   1  NaN  ISTJ  17.252986
# 3  id04  75.0   서울   NaN   2  NaN  INFP  52.667078
# 4  id05  24.0   서울  85.0   2  NaN  ISFJ  29.269869
#       f4    r1    r2
# 0   INFP  ENFJ  ENTJ
# 1   ENFP  INFJ   NaN
# 2   INFJ  ENFP  ENTP
# 3   ENFJ  INFP  ISFP
# 4   INTJ  ENFP  ENTP
# 5   ENTJ  INFP   NaN
# 6   INTP  ENTJ  ESTJ
# 7   ENTP  INFJ  INTJ
# 8   ISFP  ENFJ  ESFJ
# 9   ESFP  ISFJ  ISTJ
# 10  ISTP  ESFJ   NaN
# 11  ESTP  ISFJ  ISTJ
# 12  ISFJ  ESFP  ESTP
# 13  ESFJ  ISFP  ISTP
# 14  ISTJ  ESFP   NaN
# 15  ESTJ  INTP  ISFP

# %%
# help(pd.concat)
# ** pd.merge에 대해서 암기 # 중요

df3 = pd.merge(df1, df2, on = 'f4', how = 'left')

df3.head()
# Out:
#      id   age city    f1  f2   f3    f4         f5    r1    r2
# 0  id01   2.0   서울   NaN   0  NaN  ENFJ  91.297791  INFP  ISFP
# 1  id02   9.0   서울  70.0   1  NaN  ENFJ  60.339826  INFP  ISFP
# 2  id03  27.0   서울  61.0   1  NaN  ISTJ  17.252986  ESFP   NaN
# 3  id04  75.0   서울   NaN   2  NaN  INFP  52.667078  ENFJ  ENTJ
# 4  id05  24.0   서울  85.0   2  NaN  ISFJ  29.269869  ESFP  ESTP

# %%
import pandas as pd
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left: 'DataFrame | Series', right: 'DataFrame | Series', how: 'MergeHow' = 'inner', on: 'IndexLabel | AnyArrayLike | None' = None, left_on: 'IndexLabel | AnyArrayLike | None' = None, right_on: 'IndexLabel | AnyArrayLike | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool | None' = None, indicator: 'str | bool' = False, validate: 'str | None' = None) -> 'DataFrame'
#     Merge DataFrame or named Series objects with a database-style join.
#
#     A named Series object is treated as a DataFrame with a single named column.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
# ...

# %%
df4 = df3[df3['r2'].isnull() == False]

# ** 다른 방법: dropna
# df = df.dropna(subset = ['r2'])

print(df4.shape)

df5 = df4.iloc[:20]

df5['f2'].sum()
# Out:
# (83, 10)
# 15
